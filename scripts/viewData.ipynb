# %%
import torch

# Load the file
data = torch.load('data/webarena_lite_sft.pt')

# Check what's inside
print(type(data))
print(data.keys() if isinstance(data, dict) else data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       3 # Load the file
#       4 data = torch.load('data/webarena_lite_sft.pt')
#
# ModuleNotFoundError: No module named 'torch'

# %%
# !conda init
# Out:
# no change     /home/farhanishmam/miniconda3/condabin/conda
# no change     /home/farhanishmam/miniconda3/bin/conda
# no change     /home/farhanishmam/miniconda3/bin/conda-env
# no change     /home/farhanishmam/miniconda3/bin/activate
# no change     /home/farhanishmam/miniconda3/bin/deactivate
# no change     /home/farhanishmam/miniconda3/etc/profile.d/conda.sh
# no change     /home/farhanishmam/miniconda3/etc/fish/conf.d/conda.fish
# no change     /home/farhanishmam/miniconda3/shell/condabin/Conda.psm1
# no change     /home/farhanishmam/miniconda3/shell/condabin/conda-hook.ps1
# no change     /home/farhanishmam/miniconda3/lib/python3.13/site-packages/xontrib/conda.xsh
# no change     /home/farhanishmam/miniconda3/etc/profile.d/conda.csh
# no change     /home/farhanishmam/.bashrc
# No action taken.

# %%
# !conda activate timewarp
# Out:
# CondaError: Run 'conda init' before 'conda activate'
